# %% [markdown]
# ## Decision rees

# %%
# Import the libraries we need to use in this lab
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.svm import LinearSVC

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# For confidentiality the details are hidden so we have to work with these Vi features

# %%
labels = df['Class'].unique()
sizes = df['Class'].value_counts().values

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.3f%%')
ax.set_title('Target Variable Value Counts')
plt.show()

# %% [markdown]
# We can see that target variable has huge imbalance (thankfully) so we hae to give more importance to class 1

# %%
correlation = df.corr()['Class'].sort_values()
correlation
# Out:
# V17      -0.326481
# V14      -0.302544
# V12      -0.260593
# V10      -0.216883
# V16      -0.196539
# V3       -0.192961
# V7       -0.187257
# V18      -0.111485
# V1       -0.101347
# V9       -0.097733
# V5       -0.094974
# V6       -0.043643
# Time     -0.012323
# V24      -0.007221
# V13      -0.004570
# V15      -0.004223
# V23      -0.002685
# V22       0.000805
# V25       0.003308
# V26       0.004455
# Amount    0.005632
# V28       0.009536
# V27       0.017580
# V8        0.019875
# V20       0.020090
# V19       0.034783
# V21       0.040413
# V2        0.091289
# V4        0.133447
# V11       0.154876
# Class     1.000000
# Name: Class, dtype: float64

# %%
correlation.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Top Features are
# V11, V4, V2, V17, V14, V12, V10, V16

# %%
target = df['Class']
df.drop(columns=['Time'], inplace=True)
df.drop(columns=['Class'], inplace=True)
features = df[['V11', 'V4', 'V2', 'V17', 'V14', 'V12', 'V10', 'V16']]
print(target.head(2), features.head(2))
# Out:
# 0    0
# 1    0
# Name: Class, dtype: int64         V11        V4        V2       V17       V14       V12       V10  \
# 0 -0.551600  1.378155 -0.072781  0.207971 -0.311169 -0.617801  0.090794
# 1  1.612727  0.448154  0.266151 -0.114805 -0.143772  1.065235 -0.166974
#
#         V16
# 0 -0.470401
# 1  0.463917

# %%
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
features = normalize(features, norm='l1')

# %%
features=pd.DataFrame(features)
features
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.160557  0.289190 -0.013095  0.072750 -0.096443 -0.183698  0.024774
# 1       0.386146  0.077357  0.039391 -0.033035 -0.036655  0.260547 -0.037478
# 2       0.090956  0.039876 -0.120650  0.194281 -0.025735  0.009832  0.028350
# 3      -0.063621 -0.174821 -0.032161 -0.230937 -0.086119  0.051142 -0.014470
# 4      -0.167427  0.059120  0.110395 -0.057962 -0.242587  0.111866  0.143642
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -0.064308 -0.060141  0.251306  0.096620  0.198876  0.111828  0.164839
# 284803 -0.036226 -0.128428 -0.008212 -0.007448 -0.173397  0.225647 -0.220663
# 284804  0.158115 -0.154477 -0.071530  0.144726 -0.208850  0.024768 -0.174568
# 284805 -0.326813  0.084039  0.055415  0.103564  0.080909 -0.166227 -0.063230
# 284806 -0.285138 -0.100022 -0.032140 -0.217493 -0.024604 -0.008822 -0.235174
#
#                7
# 0      -0.159495
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(features,target,test_size=0.3,random_state=42)

# %%
w_train = compute_sample_weight('balanced', y_train)    #to handle imbalance

# %%
model1 = DecisionTreeClassifier(max_depth=4, random_state=35)
model1.fit(X_train, y_train, sample_weight=w_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=35)

# %%
model2 = LinearSVC(class_weight='balanced', random_state=35, loss='hinge', fit_intercept=False)
model2.fit(X_train, y_train)
# Out:
# LinearSVC(class_weight='balanced', fit_intercept=False, loss='hinge',
#           random_state=35)

# %%
y_pred = model1.predict(X_test)
y_pred_proba = model1.predict_proba(X_test)[:,1]    #we only need class 1's probs
y_pred_proba
# Out:
# array([0.99464882, 0.02190053, 0.02190053, ..., 0.88036488, 0.69475191,
#        0.10887331], shape=(85443,))

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print('Score: ', roc_auc)
# Out:
# Score:  0.9635121488547591

# %%
y_pred_svm = model2.decision_function(X_test)
roc_auc = roc_auc_score(y_test, y_pred_svm)
print('Score: ', roc_auc)
# Out:
# Score:  0.9659572106006058
