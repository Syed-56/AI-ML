# %% [markdown]
# # EDA Template I

# %% [markdown]
# ## Imporint Packages and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Titanic-Dataset.csv')
print('Dataset Read and Packages Imported')
# Out:
# Dataset Read and Packages Imported

# %% [markdown]
# ## Structure Pass

# %%
print("Shape of Dataset is ",df.shape)
# Out:
# Shape of Dataset is  (891, 12)

# %% [markdown]
# It Means that dataset has 891 Rows and 12 columns

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %% [markdown]
# - Data Type of our variable is pandas dataframe
# - It has 891 entries from row 0 to row 890
# - It has total 12 columns (Passenger Id to Embarked)
# - Each column's non-null entries are given (891,712,204) along their datatypes
# - Count of each datatype and memory or dataset is also given

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Top 5 entries are listed, formatted properly

# %%
df.describe()   #numeric summary
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - Basic stats, like Passenger id has 891 entries and Mean of their ages is 29.6

# %%
df.describe(include='object')   #categorical summary
# Out:
# C:\Users\ssa56\AppData\Local\Temp\ipykernel_30184\595500523.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')   #categorical summary
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %% [markdown]
# - It tells the insights on categorical values also
# - Name Sex Ticker has 891 entries but Cabin has 204 and Embarked has 889
# - There are 891 unique name and 2 unique sex (make sense)
# - Most Frequently occuring name is Braund, Mr Owen Harris and most frequent cabin is G6
# - Tells the frequency of most frequently occuring entry

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# Tells datatype of each column, it is also given in df.info()

# %% [markdown]
# ## Quality Pass

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Tells how many entries are missing/null in each column

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Tells how many entire rows are duplicate (0 here)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Tells unique entries in each column

# %% [markdown]
# ## Split Columns by type

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
print(num_cols)
cat_cols = df.select_dtypes(include=['object','category']).columns
print(cat_cols)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='str')
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='str')
# C:\Users\ssa56\AppData\Local\Temp\ipykernel_23772\3195307992.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object','category']).columns

# %% [markdown]
# Here we seperated the numerical and categorical columns in seperate variables

# %% [markdown]
# ## TARGET SPECIFIC CHECKS

# %%
df['Embarked'].value_counts(normalize=True)
# Out:
# Embarked
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: proportion, dtype: float64

# %% [markdown]
# It shows the percentage distribution (relative frequency) of the categories in your Embarked column. Like multiplying them by hundred gives you percentage.
